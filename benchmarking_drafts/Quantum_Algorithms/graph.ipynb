# %%
level1_data = []
file = open("/Users/noelnegron/QXQ_transpiler_benchmarking/Quantum_Algorithms/data1.txt", "r")
for line in file:
   number = (float) (line)
   level1_data.append(number)
file.close()

# %%
level2_data = []
file = open("/Users/noelnegron/QXQ_transpiler_benchmarking/Quantum_Algorithms/data2.txt", "r")
for line in file:
    number = (float) (line)
    level2_data.append(number)
file.close()

# %%
level3_data = []
file = open("/Users/noelnegron/QXQ_transpiler_benchmarking/Quantum_Algorithms/data3.txt", "r")
for line in file:
    number = (float) (line)
    level3_data.append(number)
file.close()
# Out:
# 56

# %%
qubits = []
for i in range(56):
    qubitsnumber_of_qubits = i + 2
    qubits.append(number_of_qubits)
# Out:
# 56

# %%
import numpy as np
import matplotlib.pyplot as plt

#Scatter Plot for Runtime after all values are collected
plt.figure(figsize=(12, 6))
        
x = np.array(qubits)
        #Calculating Line of BEST FIT: Optimization Level 1
a, b = np.polyfit(x, np.array(level1_data), 1)
        #Calculating Line of BEST FIT: Optimization Level 2
c, d = np.polyfit(x, np.array(level2_data), 1)
        #Calculating Line of BEST Fit: Optimization Level 3
e, f = np.polyfit(x, np.array(level3_data), 1)
plt.scatter(qubits, level1_data, label = "Average of Opt Level 1")
plt.plot(x, a*x+b)
plt.scatter(qubits, level2_data, label = "Average of Opt Level 2")
plt.plot(x, c*x+d)
plt.scatter(qubits, level3_data, label = "Average of Opt Level 3")
plt.plot(x, e*x+f)
plt.xlabel('Number of Qubits')
plt.ylabel('Runtime in Seconds')
plt.title('Runtime in Seconds (at each opt level)')
plt.legend()
plt.show()
